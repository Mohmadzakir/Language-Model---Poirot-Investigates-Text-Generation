# %% [markdown]
# # **1: Data Preprocessing**
# This cell is responsible for preparing the dataset before training the model. The dataset, Poirot Investigates by Agatha Christie, is loaded from a text file. To remove unnecessary parts, the code eliminates the header and footer added by Project Gutenberg. After that, the text is cleaned by removing special characters, converting everything to lowercase, and ensuring words are properly spaced.
#
# To train the language model effectively, tokenization is applied using TensorFlow’s Tokenizer, which assigns a unique number to each word while limiting the vocabulary size to 30,000 words. This helps focus on frequently used words, making the model more efficient. Pre-trained GloVe word embeddings are used to initialize word representations, allowing the model to start with a better understanding of word meanings. The text is then broken into sequences, where each sequence consists of a few words from the book, helping the model learn word patterns. These sequences are padded to a fixed length to maintain uniform input size for training.
#
# ### **Key Steps:**
#
# * Loads and cleans the dataset by removing unnecessary metadata.
# * Removes special characters and converts the text to lowercase.
# * Tokenizes words and limits vocabulary to 30,000 for efficiency.
# * Uses pre-trained GloVe embeddings for better word understanding.
# * Creates sequences of words and pads them to a fixed length.

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import re
import gensim.downloader as api
from tensorflow.keras import mixed_precision

# Enable Mixed Precision Training for GPU memory optimization
mixed_precision.set_global_policy("mixed_float16")

# Load the text file
file_path = "/content/61262-0.txt"
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

# Remove Gutenberg headers and footers
start_idx = text.find("*** START OF THIS PROJECT GUTENBERG")
end_idx = text.find("*** END OF THIS PROJECT GUTENBERG")
if start_idx != -1 and end_idx != -1:
    text = text[start_idx:end_idx]

# Clean text (Keep only words and spaces)
text = re.sub(r'[^a-zA-Z\s]', '', text).lower()
text = re.sub(r'\s+', ' ', text).strip()

# Tokenization and Vocabulary Reduction
MAX_VOCAB_SIZE = 30000
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE, filters='', oov_token="<OOV>")
tokenizer.fit_on_texts([text])
total_words = min(MAX_VOCAB_SIZE, len(tokenizer.word_index)) + 1

# Reduce Sequence Length to Save Memory
MAXLEN = 100

# Load GloVe embeddings for selected words only
glove_vectors = api.load("glove-wiki-gigaword-100")
embedding_dim = 100
embedding_matrix = np.zeros((total_words, embedding_dim))

for word, i in tokenizer.word_index.items():
    if i < MAX_VOCAB_SIZE and word in glove_vectors:
        embedding_matrix[i] = glove_vectors[word]

# Create input sequences
input_sequences = []
for line in text.split("\n"):
    token_list = tokenizer.texts_to_sequences([line])[0]
    for i in range(1, len(token_list)):
        input_sequences.append(token_list[:i+1])

# Pad sequences
input_sequences = pad_sequences(input_sequences, maxlen=MAXLEN, padding='pre')

# Create input and output labels
X, y = input_sequences[:, :-1], input_sequences[:, -1]
y = tf.keras.utils.to_categorical(y, num_classes=total_words)

print(f"✅ Vocabulary Size: {total_words}")
print(f"✅ Maximum Sequence Length: {MAXLEN}")
print("✅ Data Preprocessing Completed Successfully")
# Out:
# [==================================================] 100.0% 128.1/128.1MB downloaded
# ✅ Vocabulary Size: 6265
# ✅ Maximum Sequence Length: 100
# ✅ Data Preprocessing Completed Successfully

# %% [markdown]
# # **2: Model Definition**
# This cell defines the structure of the deep learning model for text generation. The model starts with an embedding layer that converts word indices into vector representations. These vectors are initialized using the GloVe embeddings loaded earlier, allowing the model to work with meaningful word relationships instead of just random numbers.
#
# Next, two Long Short-Term Memory (LSTM) layers are added. These layers are specialized for handling sequential data, helping the model understand and remember word order and context. To improve training stability, LayerNormalization is applied after each LSTM layer. Dropout layers are also included to prevent overfitting by randomly deactivating some neurons during training. The model ends with a dense layer that predicts the next word using a softmax activation function, which outputs probabilities for each word in the vocabulary. After defining the structure, the model is built and summarized to ensure all components are correctly set up.
#
# ### **Key Steps:**
#
# * Defines an embedding layer initialized with GloVe word vectors.
# * Adds two LSTM layers to learn word sequences and context.
# * Uses LayerNormalization for stable training.
# * Includes Dropout layers to reduce overfitting.
# * Ends with a softmax output layer that predicts the next word.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, LayerNormalization

model = Sequential([
    Embedding(input_dim=total_words, output_dim=embedding_dim, weights=[embedding_matrix], input_length=MAXLEN-1, trainable=True),
    LSTM(256, return_sequences=True),
    LayerNormalization(),
    Dropout(0.3),
    LSTM(128),
    LayerNormalization(),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(total_words, activation='softmax', dtype='float32')
])

# Build model before running summary
model.build(input_shape=(None, MAXLEN-1))
model.summary()
print("✅ Model Built and Ready for Training")
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ (None, 99, 100)             │         626,500 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm (LSTM)                          │ (None, 99, 256)             │         365,568 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization                  │ (None, 99, 256)             │             512 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 99, 256)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 128)                 │         197,120 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ layer_normalization_1                │ (None, 128)                 │             256 │
# │ (LayerNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │          16,512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 6265)                │         808,185 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,014,653 (7.69 MB)
#  Trainable params: 2,014,653 (7.69 MB)
#  Non-trainable params: 0 (0.00 B)
# ✅ Model Built and Ready for Training

# %% [markdown]
# # **3: Model Training & Saving**
# This cell handles training the model and saving the best results. Since training takes time, the model is saved in Google Drive to prevent loss of progress. The optimizer used is Adam, which helps the model learn efficiently. To ensure stable training, gradient clipping is applied to prevent sudden jumps in learning. The loss function used is categorical cross-entropy since the model is predicting a word from multiple choices in the vocabulary.
#
# To improve training, several callbacks are used. Early stopping monitors the loss and stops training if no improvement is seen for several epochs, preventing unnecessary computation. A learning rate scheduler reduces the learning rate when progress slows down, helping the model fine-tune better. Model checkpointing ensures that the best version of the model is saved during training. The model is trained for 250 epochs using a batch size of 64. Once training is complete, the final model and tokenizer are saved to Google Drive so they can be loaded later for text generation.
#
# ### **Key Steps:**
#
# * Mounts Google Drive to store training results safely.
# * Uses Adam optimizer with gradient clipping for stable learning.
# * Applies categorical cross-entropy loss for multi-class word prediction.
# * Implements early stopping, learning rate adjustment, and checkpoint saving.
# * Trains the model for 250 epochs and saves the final version.

# %%
from google.colab import drive
import os

# Mount Google Drive
drive.mount('/content/drive')

# Define save path
drive_path = "/content/drive/MyDrive/Poirot_LSTM"
os.makedirs(drive_path, exist_ok=True)

from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.optimizers import Adam
import json

# Define optimizer
optimizer = Adam(learning_rate=0.0003, clipnorm=1.0)
model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Define Callbacks
early_stopping = EarlyStopping(monitor='loss', patience=8, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='loss', factor=0.5, patience=5, min_lr=1e-6)
checkpoint = ModelCheckpoint(f"{drive_path}/poirot_lstm_best_model.keras", save_best_only=True, monitor='loss')

# Train model
num_epochs = 250
batch_size = 64
history = model.fit(X, y, epochs=num_epochs, batch_size=batch_size, verbose=1, callbacks=[early_stopping, lr_scheduler, checkpoint])

# Save final model
model.save(f"{drive_path}/poirot_lstm_final_model.keras")

# Save tokenizer
tokenizer_json = tokenizer.to_json()
with open(f"{drive_path}/tokenizer.json", "w", encoding="utf-8") as f:
    f.write(tokenizer_json)

print("✅ Training Complete & Model + Tokenizer Saved to Google Drive!")
# Out:
# Mounted at /content/drive
# Epoch 1/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 27s 21ms/step - accuracy: 0.0552 - loss: 7.0388 - learning_rate: 3.0000e-04
# Epoch 2/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 36s 20ms/step - accuracy: 0.0638 - loss: 6.3584 - learning_rate: 3.0000e-04
# Epoch 3/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.0852 - loss: 6.0302 - learning_rate: 3.0000e-04
# Epoch 4/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.0998 - loss: 5.8132 - learning_rate: 3.0000e-04
# Epoch 5/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.1053 - loss: 5.6134 - learning_rate: 3.0000e-04
# Epoch 6/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.1123 - loss: 5.4867 - learning_rate: 3.0000e-04
# Epoch 7/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 20ms/step - accuracy: 0.1207 - loss: 5.3468 - learning_rate: 3.0000e-04
# Epoch 8/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.1242 - loss: 5.2468 - learning_rate: 3.0000e-04
# Epoch 9/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.1294 - loss: 5.1119 - learning_rate: 3.0000e-04
# Epoch 10/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.1361 - loss: 5.0111 - learning_rate: 3.0000e-04
# Epoch 11/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.1386 - loss: 4.9202 - learning_rate: 3.0000e-04
# Epoch 12/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.1425 - loss: 4.8240 - learning_rate: 3.0000e-04
# Epoch 13/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.1452 - loss: 4.7250 - learning_rate: 3.0000e-04
# Epoch 14/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.1502 - loss: 4.6237 - learning_rate: 3.0000e-04
# Epoch 15/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.1540 - loss: 4.5320 - learning_rate: 3.0000e-04
# Epoch 16/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.1586 - loss: 4.4444 - learning_rate: 3.0000e-04
# Epoch 17/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.1635 - loss: 4.3583 - learning_rate: 3.0000e-04
# Epoch 18/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.1660 - loss: 4.2883 - learning_rate: 3.0000e-04
# Epoch 19/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.1729 - loss: 4.2102 - learning_rate: 3.0000e-04
# Epoch 20/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.1792 - loss: 4.1337 - learning_rate: 3.0000e-04
# Epoch 21/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.1829 - loss: 4.0657 - learning_rate: 3.0000e-04
# Epoch 22/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.1921 - loss: 3.9986 - learning_rate: 3.0000e-04
# Epoch 23/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.1973 - loss: 3.9275 - learning_rate: 3.0000e-04
# Epoch 24/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2027 - loss: 3.8594 - learning_rate: 3.0000e-04
# Epoch 25/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2057 - loss: 3.8218 - learning_rate: 3.0000e-04
# Epoch 26/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.2126 - loss: 3.7652 - learning_rate: 3.0000e-04
# Epoch 27/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.2200 - loss: 3.7016 - learning_rate: 3.0000e-04
# Epoch 28/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.2221 - loss: 3.6710 - learning_rate: 3.0000e-04
# Epoch 29/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2324 - loss: 3.6042 - learning_rate: 3.0000e-04
# Epoch 30/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2335 - loss: 3.5666 - learning_rate: 3.0000e-04
# Epoch 31/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.2417 - loss: 3.5156 - learning_rate: 3.0000e-04
# Epoch 32/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.2406 - loss: 3.4941 - learning_rate: 3.0000e-04
# Epoch 33/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.2465 - loss: 3.4554 - learning_rate: 3.0000e-04
# Epoch 34/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - accuracy: 0.2538 - loss: 3.4056 - learning_rate: 3.0000e-04
# Epoch 35/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - accuracy: 0.2565 - loss: 3.3640 - learning_rate: 3.0000e-04
# Epoch 36/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.2641 - loss: 3.3344 - learning_rate: 3.0000e-04
# Epoch 37/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.2701 - loss: 3.2890 - learning_rate: 3.0000e-04
# Epoch 38/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2713 - loss: 3.2450 - learning_rate: 3.0000e-04
# Epoch 39/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 20ms/step - accuracy: 0.2762 - loss: 3.2291 - learning_rate: 3.0000e-04
# Epoch 40/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2827 - loss: 3.1776 - learning_rate: 3.0000e-04
# Epoch 41/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.2879 - loss: 3.1455 - learning_rate: 3.0000e-04
# Epoch 42/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2937 - loss: 3.1224 - learning_rate: 3.0000e-04
# Epoch 43/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.2970 - loss: 3.0866 - learning_rate: 3.0000e-04
# Epoch 44/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.2990 - loss: 3.0687 - learning_rate: 3.0000e-04
# Epoch 45/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.3032 - loss: 3.0310 - learning_rate: 3.0000e-04
# Epoch 46/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3090 - loss: 2.9892 - learning_rate: 3.0000e-04
# Epoch 47/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.3126 - loss: 2.9669 - learning_rate: 3.0000e-04
# Epoch 48/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.3147 - loss: 2.9534 - learning_rate: 3.0000e-04
# Epoch 49/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.3226 - loss: 2.9005 - learning_rate: 3.0000e-04
# Epoch 50/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.3252 - loss: 2.8923 - learning_rate: 3.0000e-04
# Epoch 51/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3336 - loss: 2.8416 - learning_rate: 3.0000e-04
# Epoch 52/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.3347 - loss: 2.8189 - learning_rate: 3.0000e-04
# Epoch 53/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.3385 - loss: 2.7805 - learning_rate: 3.0000e-04
# Epoch 54/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3466 - loss: 2.7647 - learning_rate: 3.0000e-04
# Epoch 55/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.3513 - loss: 2.7316 - learning_rate: 3.0000e-04
# Epoch 56/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.3585 - loss: 2.7063 - learning_rate: 3.0000e-04
# Epoch 57/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.3555 - loss: 2.6986 - learning_rate: 3.0000e-04
# Epoch 58/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.3580 - loss: 2.6848 - learning_rate: 3.0000e-04
# Epoch 59/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.3644 - loss: 2.6532 - learning_rate: 3.0000e-04
# Epoch 60/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3796 - loss: 2.6039 - learning_rate: 3.0000e-04
# Epoch 61/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.3747 - loss: 2.5926 - learning_rate: 3.0000e-04
# Epoch 62/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3781 - loss: 2.5730 - learning_rate: 3.0000e-04
# Epoch 63/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.3821 - loss: 2.5515 - learning_rate: 3.0000e-04
# Epoch 64/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3909 - loss: 2.5133 - learning_rate: 3.0000e-04
# Epoch 65/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.3861 - loss: 2.5028 - learning_rate: 3.0000e-04
# Epoch 66/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.3901 - loss: 2.4800 - learning_rate: 3.0000e-04
# Epoch 67/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.4002 - loss: 2.4381 - learning_rate: 3.0000e-04
# Epoch 68/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4045 - loss: 2.4324 - learning_rate: 3.0000e-04
# Epoch 69/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4026 - loss: 2.4169 - learning_rate: 3.0000e-04
# Epoch 70/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4147 - loss: 2.3757 - learning_rate: 3.0000e-04
# Epoch 71/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.4195 - loss: 2.3566 - learning_rate: 3.0000e-04
# Epoch 72/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4197 - loss: 2.3442 - learning_rate: 3.0000e-04
# Epoch 73/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.4208 - loss: 2.3304 - learning_rate: 3.0000e-04
# Epoch 74/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4239 - loss: 2.3041 - learning_rate: 3.0000e-04
# Epoch 75/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4271 - loss: 2.2862 - learning_rate: 3.0000e-04
# Epoch 76/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4348 - loss: 2.2676 - learning_rate: 3.0000e-04
# Epoch 77/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4375 - loss: 2.2432 - learning_rate: 3.0000e-04
# Epoch 78/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.4395 - loss: 2.2189 - learning_rate: 3.0000e-04
# Epoch 79/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4419 - loss: 2.2193 - learning_rate: 3.0000e-04
# Epoch 80/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.4460 - loss: 2.1887 - learning_rate: 3.0000e-04
# Epoch 81/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4500 - loss: 2.1895 - learning_rate: 3.0000e-04
# Epoch 82/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.4547 - loss: 2.1563 - learning_rate: 3.0000e-04
# Epoch 83/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4571 - loss: 2.1477 - learning_rate: 3.0000e-04
# Epoch 84/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.4589 - loss: 2.1335 - learning_rate: 3.0000e-04
# Epoch 85/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - accuracy: 0.4623 - loss: 2.1096 - learning_rate: 3.0000e-04
# Epoch 86/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.4627 - loss: 2.0916 - learning_rate: 3.0000e-04
# Epoch 87/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.4704 - loss: 2.0666 - learning_rate: 3.0000e-04
# Epoch 88/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4745 - loss: 2.0457 - learning_rate: 3.0000e-04
# Epoch 89/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4744 - loss: 2.0510 - learning_rate: 3.0000e-04
# Epoch 90/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.4833 - loss: 2.0101 - learning_rate: 3.0000e-04
# Epoch 91/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4859 - loss: 1.9904 - learning_rate: 3.0000e-04
# Epoch 92/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.4862 - loss: 1.9954 - learning_rate: 3.0000e-04
# Epoch 93/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4963 - loss: 1.9585 - learning_rate: 3.0000e-04
# Epoch 94/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.4937 - loss: 1.9572 - learning_rate: 3.0000e-04
# Epoch 95/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4996 - loss: 1.9283 - learning_rate: 3.0000e-04
# Epoch 96/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.4979 - loss: 1.9225 - learning_rate: 3.0000e-04
# Epoch 97/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.5035 - loss: 1.9106 - learning_rate: 3.0000e-04
# Epoch 98/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5021 - loss: 1.9050 - learning_rate: 3.0000e-04
# Epoch 99/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5144 - loss: 1.8726 - learning_rate: 3.0000e-04
# Epoch 100/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.5110 - loss: 1.8627 - learning_rate: 3.0000e-04
# Epoch 101/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - accuracy: 0.5155 - loss: 1.8511 - learning_rate: 3.0000e-04
# Epoch 102/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5168 - loss: 1.8375 - learning_rate: 3.0000e-04
# Epoch 103/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5235 - loss: 1.8106 - learning_rate: 3.0000e-04
# Epoch 104/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5225 - loss: 1.7995 - learning_rate: 3.0000e-04
# Epoch 105/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5265 - loss: 1.7873 - learning_rate: 3.0000e-04
# Epoch 106/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5307 - loss: 1.7711 - learning_rate: 3.0000e-04
# Epoch 107/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5384 - loss: 1.7480 - learning_rate: 3.0000e-04
# Epoch 108/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5370 - loss: 1.7301 - learning_rate: 3.0000e-04
# Epoch 109/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5368 - loss: 1.7382 - learning_rate: 3.0000e-04
# Epoch 110/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5433 - loss: 1.7116 - learning_rate: 3.0000e-04
# Epoch 111/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5461 - loss: 1.7132 - learning_rate: 3.0000e-04
# Epoch 112/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5524 - loss: 1.6865 - learning_rate: 3.0000e-04
# Epoch 113/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5521 - loss: 1.6783 - learning_rate: 3.0000e-04
# Epoch 114/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5614 - loss: 1.6543 - learning_rate: 3.0000e-04
# Epoch 115/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5578 - loss: 1.6523 - learning_rate: 3.0000e-04
# Epoch 116/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5641 - loss: 1.6241 - learning_rate: 3.0000e-04
# Epoch 117/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5671 - loss: 1.6098 - learning_rate: 3.0000e-04
# Epoch 118/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.5706 - loss: 1.5951 - learning_rate: 3.0000e-04
# Epoch 119/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.5679 - loss: 1.5985 - learning_rate: 3.0000e-04
# Epoch 120/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.5708 - loss: 1.5893 - learning_rate: 3.0000e-04
# Epoch 121/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5735 - loss: 1.5805 - learning_rate: 3.0000e-04
# Epoch 122/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5790 - loss: 1.5544 - learning_rate: 3.0000e-04
# Epoch 123/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5796 - loss: 1.5478 - learning_rate: 3.0000e-04
# Epoch 124/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.5791 - loss: 1.5475 - learning_rate: 3.0000e-04
# Epoch 125/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5869 - loss: 1.5297 - learning_rate: 3.0000e-04
# Epoch 126/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5890 - loss: 1.5086 - learning_rate: 3.0000e-04
# Epoch 127/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5944 - loss: 1.4923 - learning_rate: 3.0000e-04
# Epoch 128/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.5917 - loss: 1.4825 - learning_rate: 3.0000e-04
# Epoch 129/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.5913 - loss: 1.4941 - learning_rate: 3.0000e-04
# Epoch 130/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6024 - loss: 1.4684 - learning_rate: 3.0000e-04
# Epoch 131/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6005 - loss: 1.4677 - learning_rate: 3.0000e-04
# Epoch 132/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6081 - loss: 1.4385 - learning_rate: 3.0000e-04
# Epoch 133/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - accuracy: 0.6057 - loss: 1.4283 - learning_rate: 3.0000e-04
# Epoch 134/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 21ms/step - accuracy: 0.6065 - loss: 1.4323 - learning_rate: 3.0000e-04
# Epoch 135/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.6105 - loss: 1.4148 - learning_rate: 3.0000e-04
# Epoch 136/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6125 - loss: 1.4005 - learning_rate: 3.0000e-04
# Epoch 137/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6177 - loss: 1.3902 - learning_rate: 3.0000e-04
# Epoch 138/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6193 - loss: 1.3697 - learning_rate: 3.0000e-04
# Epoch 139/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6245 - loss: 1.3474 - learning_rate: 3.0000e-04
# Epoch 140/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6220 - loss: 1.3466 - learning_rate: 3.0000e-04
# Epoch 141/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6281 - loss: 1.3354 - learning_rate: 3.0000e-04
# Epoch 142/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 20ms/step - accuracy: 0.6218 - loss: 1.3526 - learning_rate: 3.0000e-04
# Epoch 143/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.6272 - loss: 1.3357 - learning_rate: 3.0000e-04
# Epoch 144/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6318 - loss: 1.3218 - learning_rate: 3.0000e-04
# Epoch 145/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6328 - loss: 1.3180 - learning_rate: 3.0000e-04
# Epoch 146/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6386 - loss: 1.2977 - learning_rate: 3.0000e-04
# Epoch 147/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6391 - loss: 1.2770 - learning_rate: 3.0000e-04
# Epoch 148/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.6420 - loss: 1.2792 - learning_rate: 3.0000e-04
# Epoch 149/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6446 - loss: 1.2707 - learning_rate: 3.0000e-04
# Epoch 150/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.6439 - loss: 1.2649 - learning_rate: 3.0000e-04
# Epoch 151/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.6502 - loss: 1.2719 - learning_rate: 3.0000e-04
# Epoch 152/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6518 - loss: 1.2417 - learning_rate: 3.0000e-04
# Epoch 153/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.6545 - loss: 1.2424 - learning_rate: 3.0000e-04
# Epoch 154/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6563 - loss: 1.2194 - learning_rate: 3.0000e-04
# Epoch 155/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.6601 - loss: 1.2176 - learning_rate: 3.0000e-04
# Epoch 156/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6612 - loss: 1.2105 - learning_rate: 3.0000e-04
# Epoch 157/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.6622 - loss: 1.2058 - learning_rate: 3.0000e-04
# Epoch 158/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6619 - loss: 1.1952 - learning_rate: 3.0000e-04
# Epoch 159/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6671 - loss: 1.1753 - learning_rate: 3.0000e-04
# Epoch 160/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6662 - loss: 1.1727 - learning_rate: 3.0000e-04
# Epoch 161/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6673 - loss: 1.1702 - learning_rate: 3.0000e-04
# Epoch 162/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6722 - loss: 1.1621 - learning_rate: 3.0000e-04
# Epoch 163/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6713 - loss: 1.1470 - learning_rate: 3.0000e-04
# Epoch 164/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6804 - loss: 1.1166 - learning_rate: 3.0000e-04
# Epoch 165/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6770 - loss: 1.1296 - learning_rate: 3.0000e-04
# Epoch 166/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.6867 - loss: 1.1122 - learning_rate: 3.0000e-04
# Epoch 167/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6832 - loss: 1.1092 - learning_rate: 3.0000e-04
# Epoch 168/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6837 - loss: 1.1193 - learning_rate: 3.0000e-04
# Epoch 169/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.6900 - loss: 1.0945 - learning_rate: 3.0000e-04
# Epoch 170/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.6882 - loss: 1.0934 - learning_rate: 3.0000e-04
# Epoch 171/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6914 - loss: 1.0908 - learning_rate: 3.0000e-04
# Epoch 172/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.6903 - loss: 1.0770 - learning_rate: 3.0000e-04
# Epoch 173/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6977 - loss: 1.0713 - learning_rate: 3.0000e-04
# Epoch 174/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.6983 - loss: 1.0618 - learning_rate: 3.0000e-04
# Epoch 175/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7010 - loss: 1.0482 - learning_rate: 3.0000e-04
# Epoch 176/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.6970 - loss: 1.0511 - learning_rate: 3.0000e-04
# Epoch 177/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.6977 - loss: 1.0477 - learning_rate: 3.0000e-04
# Epoch 178/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7014 - loss: 1.0412 - learning_rate: 3.0000e-04
# Epoch 179/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7059 - loss: 1.0263 - learning_rate: 3.0000e-04
# Epoch 180/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7106 - loss: 1.0143 - learning_rate: 3.0000e-04
# Epoch 181/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7102 - loss: 1.0012 - learning_rate: 3.0000e-04
# Epoch 182/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7104 - loss: 1.0014 - learning_rate: 3.0000e-04
# Epoch 183/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7137 - loss: 1.0056 - learning_rate: 3.0000e-04
# Epoch 184/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7079 - loss: 1.0000 - learning_rate: 3.0000e-04
# Epoch 185/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7153 - loss: 0.9875 - learning_rate: 3.0000e-04
# Epoch 186/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.7124 - loss: 0.9820 - learning_rate: 3.0000e-04
# Epoch 187/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7179 - loss: 0.9830 - learning_rate: 3.0000e-04
# Epoch 188/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7227 - loss: 0.9559 - learning_rate: 3.0000e-04
# Epoch 189/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7245 - loss: 0.9528 - learning_rate: 3.0000e-04
# Epoch 190/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7194 - loss: 0.9530 - learning_rate: 3.0000e-04
# Epoch 191/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7305 - loss: 0.9329 - learning_rate: 3.0000e-04
# Epoch 192/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7299 - loss: 0.9309 - learning_rate: 3.0000e-04
# Epoch 193/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7330 - loss: 0.9183 - learning_rate: 3.0000e-04
# Epoch 194/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7330 - loss: 0.9170 - learning_rate: 3.0000e-04
# Epoch 195/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7355 - loss: 0.9095 - learning_rate: 3.0000e-04
# Epoch 196/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7331 - loss: 0.9256 - learning_rate: 3.0000e-04
# Epoch 197/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7364 - loss: 0.9076 - learning_rate: 3.0000e-04
# Epoch 198/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7364 - loss: 0.9168 - learning_rate: 3.0000e-04
# Epoch 199/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7410 - loss: 0.8888 - learning_rate: 3.0000e-04
# Epoch 200/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7407 - loss: 0.8973 - learning_rate: 3.0000e-04
# Epoch 201/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7408 - loss: 0.8961 - learning_rate: 3.0000e-04
# Epoch 202/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 22ms/step - accuracy: 0.7441 - loss: 0.8713 - learning_rate: 3.0000e-04
# Epoch 203/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7448 - loss: 0.8714 - learning_rate: 3.0000e-04
# Epoch 204/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7417 - loss: 0.8786 - learning_rate: 3.0000e-04
# Epoch 205/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7484 - loss: 0.8714 - learning_rate: 3.0000e-04
# Epoch 206/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7452 - loss: 0.8651 - learning_rate: 3.0000e-04
# Epoch 207/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 22s 22ms/step - accuracy: 0.7484 - loss: 0.8552 - learning_rate: 3.0000e-04
# Epoch 208/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7507 - loss: 0.8605 - learning_rate: 3.0000e-04
# Epoch 209/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7572 - loss: 0.8298 - learning_rate: 3.0000e-04
# Epoch 210/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7549 - loss: 0.8377 - learning_rate: 3.0000e-04
# Epoch 211/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7508 - loss: 0.8463 - learning_rate: 3.0000e-04
# Epoch 212/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7575 - loss: 0.8224 - learning_rate: 3.0000e-04
# Epoch 213/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7599 - loss: 0.8180 - learning_rate: 3.0000e-04
# Epoch 214/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7597 - loss: 0.8274 - learning_rate: 3.0000e-04
# Epoch 215/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7544 - loss: 0.8303 - learning_rate: 3.0000e-04
# Epoch 216/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.7670 - loss: 0.7904 - learning_rate: 3.0000e-04
# Epoch 217/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7606 - loss: 0.8100 - learning_rate: 3.0000e-04
# Epoch 218/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7661 - loss: 0.7955 - learning_rate: 3.0000e-04
# Epoch 219/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7634 - loss: 0.8053 - learning_rate: 3.0000e-04
# Epoch 220/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7646 - loss: 0.7923 - learning_rate: 3.0000e-04
# Epoch 221/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7669 - loss: 0.7928 - learning_rate: 3.0000e-04
# Epoch 222/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7713 - loss: 0.7711 - learning_rate: 3.0000e-04
# Epoch 223/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7726 - loss: 0.7831 - learning_rate: 3.0000e-04
# Epoch 224/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7725 - loss: 0.7667 - learning_rate: 3.0000e-04
# Epoch 225/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7696 - loss: 0.7755 - learning_rate: 3.0000e-04
# Epoch 226/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7707 - loss: 0.7739 - learning_rate: 3.0000e-04
# Epoch 227/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7741 - loss: 0.7600 - learning_rate: 3.0000e-04
# Epoch 228/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7784 - loss: 0.7619 - learning_rate: 3.0000e-04
# Epoch 229/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 22ms/step - accuracy: 0.7788 - loss: 0.7463 - learning_rate: 3.0000e-04
# Epoch 230/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7771 - loss: 0.7452 - learning_rate: 3.0000e-04
# Epoch 231/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7795 - loss: 0.7494 - learning_rate: 3.0000e-04
# Epoch 232/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7770 - loss: 0.7400 - learning_rate: 3.0000e-04
# Epoch 233/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7854 - loss: 0.7261 - learning_rate: 3.0000e-04
# Epoch 234/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 22ms/step - accuracy: 0.7829 - loss: 0.7301 - learning_rate: 3.0000e-04
# Epoch 235/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7852 - loss: 0.7205 - learning_rate: 3.0000e-04
# Epoch 236/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7832 - loss: 0.7254 - learning_rate: 3.0000e-04
# Epoch 237/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.7846 - loss: 0.7203 - learning_rate: 3.0000e-04
# Epoch 238/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7888 - loss: 0.7194 - learning_rate: 3.0000e-04
# Epoch 239/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 17s 21ms/step - accuracy: 0.7860 - loss: 0.7239 - learning_rate: 3.0000e-04
# Epoch 240/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7887 - loss: 0.7145 - learning_rate: 3.0000e-04
# Epoch 241/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.7929 - loss: 0.7066 - learning_rate: 3.0000e-04
# Epoch 242/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7883 - loss: 0.7155 - learning_rate: 3.0000e-04
# Epoch 243/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7902 - loss: 0.7013 - learning_rate: 3.0000e-04
# Epoch 244/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.7933 - loss: 0.7034 - learning_rate: 3.0000e-04
# Epoch 245/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.7937 - loss: 0.6977 - learning_rate: 3.0000e-04
# Epoch 246/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 21s 22ms/step - accuracy: 0.7942 - loss: 0.6872 - learning_rate: 3.0000e-04
# Epoch 247/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 18s 21ms/step - accuracy: 0.7959 - loss: 0.6817 - learning_rate: 3.0000e-04
# Epoch 248/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.7960 - loss: 0.6789 - learning_rate: 3.0000e-04
# Epoch 249/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 20s 21ms/step - accuracy: 0.8014 - loss: 0.6637 - learning_rate: 3.0000e-04
# Epoch 250/250
# 821/821 ━━━━━━━━━━━━━━━━━━━━ 22s 23ms/step - accuracy: 0.7986 - loss: 0.6725 - learning_rate: 3.0000e-04
# ✅ Training Complete & Model + Tokenizer Saved to Google Drive!

# %% [markdown]
# # **4: Model Loading & Text Generation**
# This cell loads the trained model and tokenizer to generate new text. It first mounts Google Drive to access the saved model files. The trained model and tokenizer are then loaded from their respective locations. If the files are missing, the script prints an error message to alert the user.
#
# The text generation function works by taking an input prompt (a few words) and predicting the next words. It first converts the input text into numerical tokens and pads them to match the training format. The model then predicts probabilities for the next word. To make the text more diverse and less repetitive, a technique called temperature scaling is used. A lower temperature makes predictions more deterministic, while a higher temperature introduces more randomness. Additionally, a sampling rate controls how often a random word is chosen instead of the most likely word. The function is demonstrated by generating text starting with "The great", showing how the model continues the sentence in Agatha Christie’s writing style.
#
# ### **Key Steps:**
#
# * Mounts Google Drive and loads the trained model and tokenizer.
# * Checks if files are missing and displays an error if needed.
# * Converts input text into numerical tokens and pads them.
# * Uses temperature scaling and sampling to generate diverse text.
# * Demonstrates text generation with an example prompt.

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import tokenizer_from_json
from google.colab import drive
import os
import json  # Ensure JSON module is imported
import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Mount Google Drive
drive.mount('/content/drive')

# Define save path
drive_path = "/content/drive/MyDrive/Poirot_LSTM"
os.makedirs(drive_path, exist_ok=True)

# Load trained model
model_path = f"{drive_path}/poirot_lstm_final_model.keras"
tokenizer_path = f"{drive_path}/tokenizer.json"

if os.path.exists(model_path):
    model = load_model(model_path)
    print("✅ Model Loaded Successfully!")
else:
    print("❌ Model file not found!")

if os.path.exists(tokenizer_path):
    with open(tokenizer_path, "r", encoding="utf-8") as f:
        tokenizer_data = json.load(f)  # JSON module was missing
    tokenizer = tokenizer_from_json(json.dumps(tokenizer_data))
    print("✅ Tokenizer Loaded Successfully!")
else:
    print("❌ Tokenizer file not found!")

# Ensure MAXLEN is defined
MAXLEN = 100  # Set this to the correct max length used during training

# Generate Text
def generate_text(seed_text, next_words=20, temperature=0.8, sampling_rate=0.7):
    for _ in range(next_words):
        token_list = tokenizer.texts_to_sequences([seed_text])[0]
        token_list = pad_sequences([token_list], maxlen=MAXLEN-1, padding='pre')
        predicted_probs = model.predict(token_list, verbose=0)[0]
        predicted_probs = np.exp(np.log(predicted_probs) / temperature)
        predicted_probs /= np.sum(predicted_probs)
        predicted = np.random.choice(len(predicted_probs), p=predicted_probs) if np.random.rand() < sampling_rate else np.argmax(predicted_probs)
        seed_text += " " + tokenizer.index_word.get(predicted, "<OOV>")
    return seed_text

# Example Usage
print(generate_text("The great", next_words=20, temperature=0.8))
# Out:
# Mounted at /content/drive
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'adam', because it has 32 variables whereas the saved optimizer has 36 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))
# ✅ Model Loaded Successfully!
# ✅ Tokenizer Loaded Successfully!
# <ipython-input-1-0f3aa682eeb1>:43: RuntimeWarning: divide by zero encountered in log
#   predicted_probs = np.exp(np.log(predicted_probs) / temperature)
# The great financier was perfectly right in the afternoon poirot gave a policeman getting of his own flesh and cry the nephew
